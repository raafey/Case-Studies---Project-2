# %%
from read_data import process_data
from changepoint_detection import *
from eigen_freq import *
from acf import *

# %%
data = process_data()

# %%
selected_sensors = ["CH1_Moment", "CH2_Kraft"]
changepoints = generate_changepoints(data, selected_sensors)
# Out:
# c:\Users\Raafe\AppData\Local\Programs\Python\Python38\lib\site-packages\ruptures\costs\costnormal.py:27: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(

# %%
selected_datasets = {
 'V2_00001':3,
 'V10_0001':3,
 'V6_00001':3,
 'V17_0001':3,
 'V20_0001':3,
 'V24_0001':3,
 'V25a_001':3
}
sensor = "CH1_Moment"
plot_acf_by_dataset(list(selected_datasets.keys()), data, sensor, changepoints, selected_datasets, (10, 14), "vdsets_ch1_acf_3cpt.pdf")

# %%
selected_datasets = {
 'V2_00001':2,
 'V10_0001':4,
 'V6_00001':4,
 'V17_0001':3,
 'V20_0001':4,
 'V24_0001':3,
 'V25a_001':3
}

sensor = "CH2_Kraft"
plot_acf_by_dataset(list(selected_datasets.keys()), data, sensor, changepoints, selected_datasets, (10, 14), "vdsets_ch2_acf_3cpt.pdf")
