# %%
from read_data import process_data
from changepoint_detection import *
from eigen_freq import *
from acf import *

# %%
data = process_data()

# %%
selected_sensors = ["CH1_Moment", "CH2_Kraft"]
changepoints = generate_changepoints(data, selected_sensors)
# Out:
# /Users/aymanehachcham/miniconda3/envs/tad/lib/python3.10/site-packages/ruptures/costs/costnormal.py:27: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(

# %%
selected_datasets = {
 'V2_00001':3,
 'V10_0001':3,
}
sensor = "CH1_Moment"
plot_acf_by_dataset(list(selected_datasets.keys()), data, sensor, changepoints, selected_datasets, (10, 14), "vdsets_ch1_acf_3cpt.pdf")
# Out:
# /Users/aymanehachcham/Documents/TU Dortmund/Case Studies 2023/Case-Studies---Project-2/code/acf.py:19: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   after = original_data.loc[changepoint_indexes[cpt-1]:][0:20000]

# %%
selected_datasets = {
 'V2_00001':2,
 'V10_0001':4,
 'V6_00001':4,
 'V17_0001':3,
 'V20_0001':4,
 'V24_0001':3,
 'V25a_001':3
}

sensor = "CH2_Kraft"
plot_acf_by_dataset(list(selected_datasets.keys()), data, sensor, changepoints, selected_datasets, (10, 14), "vdsets_ch2_acf_3cpt.pdf")
