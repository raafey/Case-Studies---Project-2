# %% [markdown]
# Project: 2
#
# Group: 3
#
# Group Members:
#  - Muhammad Raafey Tariq (231806)
#  - Farrukh Ahmed (230614)
#  - Amirreza Khamehchin Khiabani (230891)
#  - Aymane Hachcham (236392)

# %%
from read_data import *

# %%
data = process_data()

# %%
plot_channels(data, 'V2_00001')

# %%
plot_channels(data, 'V10_0001')

# %%
plot_channels(data, 'D0400001')

# %%
plot_channels(data, 'D0600001')

# %%
plot_channels(data, 'V6_00001')

# %%
plot_channels(data, 'V17_0001')

# %%
plot_channels(data, 'V20_0001')

# %%
plot_channels(data, 'V24_0001')

# %%
plot_channels(data, 'V25a_001')
